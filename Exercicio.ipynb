# %% [markdown]
# Mostrando DataSet

# %%
import pandas as pd
url = "dataset/Data-Science-Job_Listing.csv"
dados =pd.read_csv(url)
dados
# Out:
#      Position                                          Job Title  \
# 0           1                    Associate Stop Loss Underwriter
# 1           2                            Manager of Data Science
# 2           3                        Senior Data Product Manager
# 3           4                           Oncology Nurse Navigator
# 4           5  Head of Artificial Intelligence – Americas Region
# ..        ...                                                ...
# 495       496                                Cloud Administrator
# 496       497                             Robotics Engineer (AI)
# 497       498  Tchr of English- Newark School of Data Science...
# 498       499                                       Statistician
# 499       500  Quantitative Analytics Manager - Data Modeling...
#
#                        Company Name                    Location  \
# 0         The Insurance Center\n2.7                Onalaska, WI
# ...

# %% [markdown]
# Mostrando os 10 primeiros

# %%
dados.head(10)
# Out:
#    Position                                          Job Title  \
# 0         1                    Associate Stop Loss Underwriter
# 1         2                            Manager of Data Science
# 2         3                        Senior Data Product Manager
# 3         4                           Oncology Nurse Navigator
# 4         5  Head of Artificial Intelligence – Americas Region
# 5         6                                         IT Manager
# 6         7  Data Center Services Technician - IT, Crypto M...
# 7         8               Data Center Construction Coordinator
# 8         9                              Senior AIOps Engineer
# 9        10        Software Measurement and Estimation Analyst
#
#                                         Company Name        Location  \
# 0                          The Insurance Center\n2.7    Onalaska, WI
# 1                                Nuvative, Inc.\n3.4     Wichita, KS
# ...

# %% [markdown]
# Mostrandos os 10 últimos

# %%
dados.tail(10)
# Out:
#      Position                                          Job Title  \
# 490       491                                      Data Engineer
# 491       492         Manager, Data Science Platform Engineering
# 492       493                           Director of Data Science
# 493       494                       Vice President, Data Science
# 494       495                           Analytics Solution Owner
# 495       496                                Cloud Administrator
# 496       497                             Robotics Engineer (AI)
# 497       498  Tchr of English- Newark School of Data Science...
# 498       499                                       Statistician
# 499       500  Quantitative Analytics Manager - Data Modeling...
#
#                        Company Name                    Location  \
# 490            Inspur USA Inc.\n3.6                 Seattle, WA
# 491                  Dave Inc.\n4.0                      Remote
# ...
